# %% [markdown]
# # NLP Grammar Checker

# %% [markdown]
# ## Dataset Processing

# %% [markdown]
# #### Imports

# %%
import pandas as pd

# %% [markdown]
# Dataset Load

# %%
original_ds=pd.read_csv('datasets/grammar_error_dataset.csv')

print(original_ds)
# Out:
#         ID Learner_Proficiency       Topic                  Original_Sentence  \
# 0        1            Advanced      Health              He bought two breads.
# 1        2            Advanced      Health        She go to market yesterday.
# 2        3            Advanced      Sports  Always I drink coffee in morning.
# 3        4            Beginner      Sports  Always I drink coffee in morning.
# 4        5            Beginner  Technology       He is married with a doctor.
# ...    ...                 ...         ...                                ...
# 1745  1746            Advanced      Sports      I have an homework to finish.
# 1746  1747            Advanced  Technology  Always I drink coffee in morning.
# 1747  1748            Beginner        Work      I have an homework to finish.
# 1748  1749            Beginner        Work        She go to market yesterday.
# 1749  1750            Advanced      Health            The students was happy.
#
# ...
